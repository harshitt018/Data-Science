# %% [markdown]
# # **Pandas Library**

# %% [markdown]
# **Installing pandas as importing pandas as pd**

# %%
pip install pandas

# %% [markdown]
# **Viewing head.**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# **Viewing tail.**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %% [markdown]
# **Viewing number of columns and rows**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df.shape
# Out:
# (418, 11)

# %% [markdown]
# **Viewing name of the columns**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# **Viewing index.**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %% [markdown]
# **Values with their counts in a particular column.**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# **Creating Dataframe.**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df_empty = pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Creating a table using dictionary.**

# %%
import pandas as pd # data processing.
import numpy as np # for linear algebra.
train = pd.read_csv(r'/content/sample_data/test.csv') # copy path of the file.
df = train.copy()
df_empty = pd.DataFrame()
df_empty.head()
student_dict = {'Name':['A','B','C'],'Age':[24,18,17],'Roll_no':[1,2,3]}
df_student = pd.DataFrame(student_dict).reset_index(drop=True)
df_student.head()
# Out:
#   Name  Age  Roll_no
# 0    A   24        1
# 1    B   18        2
# 2    C   17        3

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# **Counting null values on a whole df.**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# **On a particular column.**

# %%
df['Age'].isnull().sum()
# Out:
# 86

# %% [markdown]
# **Replace the null value.**

# %%
df['Age'].fillna(df['Age'].mean(),inplace = True)
df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Modify/Add new column(s).**

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df['Sex'] = df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Pclass                                          Name Sex  \
# 0          892       3                              Kelly, Mr. James   0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)   1
# 2          894       2                     Myles, Mr. Thomas Francis   0
# 3          895       3                              Wirz, Mr. Albert   0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# **Finding last name and first name from name column.**

# %%
df['last_name'] = df['Name'].apply(lambda x:x.split(',')[0])
df['first_name'] = df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))
df.head()
# Out:
#    PassengerId  Pclass                                          Name Sex  \
# 0          892       3                              Kelly, Mr. James   0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)   1
# 2          894       2                     Myles, Mr. Thomas Francis   0
# 3          895       3                              Wirz, Mr. Albert   0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked last_name  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name
# 0                            Mr. James
# 1             Mrs. James (Ellen Needs)
# ...

# %% [markdown]
# **Sets to 1 for men in 3rd class.**

# %%
df['Third&Men'] = df.apply(lambda row : int(row['Pclass'] == 3 and row['Sex'] == "0"), axis = 1)
df.head()
# Out:
#    PassengerId  Pclass                                          Name Sex  \
# 0          892       3                              Kelly, Mr. James   0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)   1
# 2          894       2                     Myles, Mr. Thomas Francis   0
# 3          895       3                              Wirz, Mr. Albert   0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked last_name  \
# 0  34.5      0      0   330911   7.8292   NaN        Q     Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S    Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q     Myles
# 3  27.0      0      0   315154   8.6625   NaN        S      Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name  Third&Men
# 0                            Mr. James          1
# ...

# %% [markdown]
# **Deleting columns**

# %%
df = df.drop(['PassengerId'], axis = 1)
df.head()
# Out:
#    Pclass                                          Name Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James   0  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)   1  47.0      1
# 2       2                     Myles, Mr. Thomas Francis   0  62.0      0
# 3       3                              Wirz, Mr. Albert   0  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   1  22.0      1
#
#    Parch   Ticket     Fare Cabin Embarked last_name  \
# 0      0   330911   7.8292   NaN        Q     Kelly
# 1      0   363272   7.0000   NaN        S    Wilkes
# 2      0   240276   9.6875   NaN        Q     Myles
# 3      0   315154   8.6625   NaN        S      Wirz
# 4      1  3101298  12.2875   NaN        S  Hirvonen
#
#                             first_name  Third&Men
# 0                            Mr. James          1
# 1             Mrs. James (Ellen Needs)          0
# 2                   Mr. Thomas Francis          0
# ...

# %% [markdown]
# **Renaming columns**

# %%
df = df.rename(columns  = {'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Pclass                                     Full Name Gender   Age  SibSp  \
# 0       3                              Kelly, Mr. James      0  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)      1  47.0      1
# 2       2                     Myles, Mr. Thomas Francis      0  62.0      0
# 3       3                              Wirz, Mr. Albert      0  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1  22.0      1
#
#    Parch   Ticket     Fare Cabin Embarked   Surname  \
# 0      0   330911   7.8292   NaN        Q     Kelly
# 1      0   363272   7.0000   NaN        S    Wilkes
# 2      0   240276   9.6875   NaN        Q     Myles
# 3      0   315154   8.6625   NaN        S      Wirz
# 4      1  3101298  12.2875   NaN        S  Hirvonen
#
#                              Full Name  Third&Men
# 0                            Mr. James          1
# 1             Mrs. James (Ellen Needs)          0
# ...

# %%
df_student.head()
# Out:
#   Name  Age  Roll_no
# 0    A   24        1
# 1    B   18        2
# 2    C   17        3

# %% [markdown]
# **Rename Roll_no to Roll in student**

# %%
df = df_student.rename(columns  = {'Roll_no':'Roll'})
df.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %% [markdown]
# **Add gender column in student.**

# %%
df_student.insert(2, "Gender", ['Male','Female','Male'],True)
df_student.head()
# Out:
#   Name  Age  Gender  Roll_no
# 0    A   24    Male        1
# 1    B   18  Female        2
# 2    C   17    Male        3

# %%
df_student['Gender'] = df_student['Gender'].map({"Male":'0',"Female":'1'})
df_student.head()
# Out:
#   Name  Age Gender  Roll_no
# 0    A   24      0        1
# 1    B   18      1        2
# 2    C   17      0        3
