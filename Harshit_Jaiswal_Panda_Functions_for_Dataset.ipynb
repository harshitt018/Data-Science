# %% [markdown]
# # **Data Wrangling**
# **3.1 Creating a Data Frame**

# %%
import pandas as pd
dataframes = pd.DataFrame()

# %% [markdown]
# **3.2 Describing the Data**

# %%
df = pd.read_csv("/content/sample_data/test.csv")
print(df.head(2))
print("Dimensions: {}".format(df.shape))
df.describe()
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# Dimensions: (418, 11)
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# **3.3 Navigating DataFrames**

# %%
# select the first row
print("First row : \n",df.iloc[0])

# select three rows
print("Three rows : \n",df.iloc[1:4])

# all rows up to and including the fourth row
print("All rows up to and including the fourth row : \n",df.iloc[:4])

# set index
df = df.set_index(df['Name'])
# Out:
# First row :
#  PassengerId                 892
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object
# Three rows :
#     PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
# 3          895       3                  Wirz, Mr. Albert    male  27.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q
# 3      0  315154  8.6625   NaN        S
# All rows up to and including the fourth row :
#     PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
# 3          895       3                  Wirz, Mr. Albert    male  27.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q
# 3      0  315154  8.6625   NaN        S

# %% [markdown]
# **3.4 Selecting Rows based on Conditionals**

# %%
# select top two rows where column 'sex' is 'female'
df [df ['Sex'] == 'female'].head (2)
# Out:
#                                               PassengerId  Pclass  \
# Name
# Wilkes, Mrs. James (Ellen Needs)                      893       3
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3
#
#                                                                                       Name  \
# Name
# Wilkes, Mrs. James (Ellen Needs)                          Wilkes, Mrs. James (Ellen Needs)
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# Wilkes, Mrs. James (Ellen Needs)              female  47.0      1      0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#                                                Ticket     Fare Cabin Embarked
# Name
# Wilkes, Mrs. James (Ellen Needs)               363272   7.0000   NaN        S
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  3101298  12.2875   NaN        S

# %%
# multiple conditions
df [(df['Sex'] == 'female') & (df ['Age'] >= 65)]
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Cavendish, Mrs. Tyrell William (Julia Florence ...          988       1
#
#                                                                                                  Name  \
# Name
# Cavendish, Mrs. Tyrell William (Julia Florence ...  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#                                                        Sex   Age  SibSp  \
# Name
# Cavendish, Mrs. Tyrell William (Julia Florence ...  female  76.0      1
#
#                                                     Parch Ticket   Fare Cabin  \
# Name
# Cavendish, Mrs. Tyrell William (Julia Florence ...      0  19877  78.85   C46
#
#                                                    Embarked
# Name
# Cavendish, Mrs. Tyrell William (Julia Florence ...        S

# %% [markdown]
# **3.5 Replacing Values**

# %%
# replace any instance of 'female' with Woman
df ['Sex'].replace('female', 'Woman').head (2)
# Out:
# Name
# Kelly, Mr. James                     male
# Wilkes, Mrs. James (Ellen Needs)    Woman
# Name: Sex, dtype: object

# %%
# replace any instance of 'female' with Woman
df ['Sex'].replace(['female', 'male'], ['Woman', 'Man']). head (5)
# Out:
# Name
# Kelly, Mr. James                                  Man
# Wilkes, Mrs. James (Ellen Needs)                Woman
# Myles, Mr. Thomas Francis                         Man
# Wirz, Mr. Albert                                  Man
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)    Woman
# Name: Sex, dtype: object

# %%
df.replace(1, "One").head (2)
# Out:
#                                   PassengerId Pclass  \
# Name
# Kelly, Mr. James                          892      3
# Wilkes, Mrs. James (Ellen Needs)          893      3
#
#                                                               Name     Sex  \
# Name
# Kelly, Mr. James                                  Kelly, Mr. James    male
# Wilkes, Mrs. James (Ellen Needs)  Wilkes, Mrs. James (Ellen Needs)  female
#
#                                    Age SibSp Parch  Ticket    Fare Cabin  \
# Name
# Kelly, Mr. James                  34.5     0     0  330911  7.8292   NaN
# Wilkes, Mrs. James (Ellen Needs)  47.0   One     0  363272  7.0000   NaN
#
#                                  Embarked
# Name
# Kelly, Mr. James                        Q
# Wilkes, Mrs. James (Ellen Needs)        S

# %% [markdown]
# **3.6 Renaming Columns**

# %%
df.rename(columns={'PClass': 'Passenger Class'}).head (2)
# Out:
#                                   PassengerId  Pclass  \
# Name
# Kelly, Mr. James                          892       3
# Wilkes, Mrs. James (Ellen Needs)          893       3
#
#                                                               Name     Sex  \
# Name
# Kelly, Mr. James                                  Kelly, Mr. James    male
# Wilkes, Mrs. James (Ellen Needs)  Wilkes, Mrs. James (Ellen Needs)  female
#
#                                    Age  SibSp  Parch  Ticket    Fare Cabin  \
# Name
# Kelly, Mr. James                  34.5      0      0  330911  7.8292   NaN
# Wilkes, Mrs. James (Ellen Needs)  47.0      1      0  363272  7.0000   NaN
#
#                                  Embarked
# Name
# Kelly, Mr. James                        Q
# Wilkes, Mrs. James (Ellen Needs)        S

# %%
df.rename (columns={'PClass': 'Passenger Class', 'Sex': 'Gender'}).head (2)
# Out:
#                                   PassengerId  Pclass  \
# Name
# Kelly, Mr. James                          892       3
# Wilkes, Mrs. James (Ellen Needs)          893       3
#
#                                                               Name  Gender  \
# Name
# Kelly, Mr. James                                  Kelly, Mr. James    male
# Wilkes, Mrs. James (Ellen Needs)  Wilkes, Mrs. James (Ellen Needs)  female
#
#                                    Age  SibSp  Parch  Ticket    Fare Cabin  \
# Name
# Kelly, Mr. James                  34.5      0      0  330911  7.8292   NaN
# Wilkes, Mrs. James (Ellen Needs)  47.0      1      0  363272  7.0000   NaN
#
#                                  Embarked
# Name
# Kelly, Mr. James                        Q
# Wilkes, Mrs. James (Ellen Needs)        S

# %% [markdown]
# **3.7 Finding the Min, Max, Sum, Average, and Count**

# %%
print('Maximum: {}'.format(df ['Age'].max()))
print('Minimum: {}'.format(df['Age'].min()))
print('Mean: {}'.format(df ['Age'].mean()))
print('Sum: {}'.format(df ['Age'].sum()))
print('Count: {}'.format(df ['Age'].count()))
# Out:
# Maximum: 76.0
# Minimum: 0.17
# Mean: 30.272590361445783
# Sum: 10050.5
# Count: 332

# %% [markdown]
# **3.8 Finding Unique Values**

# %%
# unique will return an array of all unique values in a column
df ['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# value_counts will display all unique values with the number of times each value appears
df ['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %% [markdown]
# **3.9 Handling Missing Values**

# %%
# select missing values, show 2 rows
df [df ['Age'].isnull()].head (2)
# Out:
#                                       PassengerId  Pclass  \
# Name
# Ilieff, Mr. Ylio                              902       3
# Flegenheim, Mrs. Alfred (Antoinette)          914       1
#
#                                                                       Name  \
# Name
# Ilieff, Mr. Ylio                                          Ilieff, Mr. Ylio
# Flegenheim, Mrs. Alfred (Antoinette)  Flegenheim, Mrs. Alfred (Antoinette)
#
#                                          Sex  Age  SibSp  Parch    Ticket  \
# Name
# Ilieff, Mr. Ylio                        male  NaN      0      0    349220
# Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0      0  PC 17598
#
#                                          Fare Cabin Embarked
# Name
# Ilieff, Mr. Ylio                       7.8958   NaN        S
# Flegenheim, Mrs. Alfred (Antoinette)  31.6833   NaN        S

# %% [markdown]
# **3.10 Deleting a Column**

# %%
# axis=1 means the column axis
df.drop('Age', axis=1).head (2)
# Out:
#                                   PassengerId  Pclass  \
# Name
# Kelly, Mr. James                          892       3
# Wilkes, Mrs. James (Ellen Needs)          893       3
#
#                                                               Name     Sex  \
# Name
# Kelly, Mr. James                                  Kelly, Mr. James    male
# Wilkes, Mrs. James (Ellen Needs)  Wilkes, Mrs. James (Ellen Needs)  female
#
#                                   SibSp  Parch  Ticket    Fare Cabin Embarked
# Name
# Kelly, Mr. James                      0      0  330911  7.8292   NaN        Q
# Wilkes, Mrs. James (Ellen Needs)      1      0  363272  7.0000   NaN        S

# %% [markdown]
# **3.11 Deleting a Row**

# %%
# create new dataframe excluding the rows you want to delete
df [df ['Sex'] != 'male'].head (2)
# Out:
#                                               PassengerId  Pclass  \
# Name
# Wilkes, Mrs. James (Ellen Needs)                      893       3
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3
#
#                                                                                       Name  \
# Name
# Wilkes, Mrs. James (Ellen Needs)                          Wilkes, Mrs. James (Ellen Needs)
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# Wilkes, Mrs. James (Ellen Needs)              female  47.0      1      0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#                                                Ticket     Fare Cabin Embarked
# Name
# Wilkes, Mrs. James (Ellen Needs)               363272   7.0000   NaN        S
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)  3101298  12.2875   NaN        S

# %%
# delete a row by matching a unique value
df [df['Name'] != 'Allison, Miss Helen Loraine'].head(2)
# Out:
#                                   PassengerId  Pclass  \
# Name
# Kelly, Mr. James                          892       3
# Wilkes, Mrs. James (Ellen Needs)          893       3
#
#                                                               Name     Sex  \
# Name
# Kelly, Mr. James                                  Kelly, Mr. James    male
# Wilkes, Mrs. James (Ellen Needs)  Wilkes, Mrs. James (Ellen Needs)  female
#
#                                    Age  SibSp  Parch  Ticket    Fare Cabin  \
# Name
# Kelly, Mr. James                  34.5      0      0  330911  7.8292   NaN
# Wilkes, Mrs. James (Ellen Needs)  47.0      1      0  363272  7.0000   NaN
#
#                                  Embarked
# Name
# Kelly, Mr. James                        Q
# Wilkes, Mrs. James (Ellen Needs)        S

# %%
# delete a row by index df [df.index
df[df.index != 0].head (2)
# Out:
#                                   PassengerId  Pclass  \
# Name
# Kelly, Mr. James                          892       3
# Wilkes, Mrs. James (Ellen Needs)          893       3
#
#                                                               Name     Sex  \
# Name
# Kelly, Mr. James                                  Kelly, Mr. James    male
# Wilkes, Mrs. James (Ellen Needs)  Wilkes, Mrs. James (Ellen Needs)  female
#
#                                    Age  SibSp  Parch  Ticket    Fare Cabin  \
# Name
# Kelly, Mr. James                  34.5      0      0  330911  7.8292   NaN
# Wilkes, Mrs. James (Ellen Needs)  47.0      1      0  363272  7.0000   NaN
#
#                                  Embarked
# Name
# Kelly, Mr. James                        Q
# Wilkes, Mrs. James (Ellen Needs)        S

# %% [markdown]
# **3.12 Grouping Rows by Values**

# %%
df.groupby( 'Cabin') ['Name'].count()
# Out:
# Cabin
# A11      1
# A18      1
# A21      1
# A29      1
# A34      2
#         ..
# F G63    1
# F2       1
# F33      1
# F4       2
# G6       1
# Name: Name, Length: 76, dtype: int64

# %% [markdown]
# **3.13 Looping Over a column**

# %%
# for .. in.. loop
for name in df ['Name'][0:2]:
  print(name.upper())
# Out:
# KELLY, MR. JAMES
# WILKES, MRS. JAMES (ELLEN NEEDS)

# %%
# list comprehension (more "pythonic")
[name.upper() for name in df ['Name'] [0:2]]
# Out:
# ['KELLY, MR. JAMES', 'WILKES, MRS. JAMES (ELLEN NEEDS)']

# %% [markdown]
# **3.14 Applying a Function Over All Elements in a Column**

# %%
def uppercase(x):
  return x.upper()
df ['Name'].apply(uppercase) [0:2]
# Out:
# Name
# Kelly, Mr. James                                    KELLY, MR. JAMES
# Wilkes, Mrs. James (Ellen Needs)    WILKES, MRS. JAMES (ELLEN NEEDS)
# Name: Name, dtype: object

# %% [markdown]
# **3.15 Applying a Function to Groups**

# %%
df.groupby('Sex').apply(lambda x: x.count())
# Out:
#         PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          152     152   152  152  127    152    152     152   152
# male            266     266   266  266  205    266    266     266   265
#
#         Cabin  Embarked
# Sex
# female     44       152
# male       47       266

# %% [markdown]
# **3.16 Concatenating DataFrames**

# %%
import numpy as np
numerical_df=df.select_dtypes(include=[np.number])
numerical_df.head()
numerical_df=df.select_dtypes(include=[np.number])
numerical_df.head()
categorical_df = pd.DataFrame({
# Define the columns and data for the categorical DataFrame here
})
comb_df = pd.concat([numerical_df,categorical_df],axis=1)
comb_df.head()
# Out:
#                                               PassengerId  Pclass   Age  \
# Name
# Kelly, Mr. James                                      892       3  34.5
# Wilkes, Mrs. James (Ellen Needs)                      893       3  47.0
# Myles, Mr. Thomas Francis                             894       2  62.0
# Wirz, Mr. Albert                                      895       3  27.0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  22.0
#
#                                               SibSp  Parch     Fare
# Name
# Kelly, Mr. James                                  0      0   7.8292
# Wilkes, Mrs. James (Ellen Needs)                  1      0   7.0000
# Myles, Mr. Thomas Francis                         0      0   9.6875
# Wirz, Mr. Albert                                  0      0   8.6625
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1      1  12.2875
