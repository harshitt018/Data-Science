# %%
#Open the text file, specifying the encoding
text_file = open("/content/“Twin Stars Aloft” by Charles Kingsley.txt", encoding="latin-1")

# %%
#Read the data
text = text_file.read()

# %%
#Datatype of the data read :
print (type(text))
print("\n")
# Out:
# <class 'str'>

# %%
#Print the text :
print(text)
print("\n")
#Length of the text :
print (len(text))
# Out:
# Twin stars, aloft in ether clear,
# Around each other roll alway,
# Within one common atmosphere
# Of their own mutual light and day.
#
# And myriad happy eyes are bent
# Upon their changeless love alway;
# As strengthened by their one intent,
# They pour the flood of life and day.
#
# So we, through this worldÂs waning night,
# Shall, hand in hand, pursue our way;
# Shed round us order, love, and light,
# And shine unto the perfect day.
#
#
# 418

# %%
#Import required libraries :
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
#Tokenize the text by sentences :
sentences = sent_tokenize(text)
#How many sentences are there? :
print (len(sentences))
#Print the sentences :
#print(sentences)
sentences
# Out:
# 3
# ['Twin stars, aloft in ether clear,\nAround each other roll alway,\nWithin one common atmosphere\nOf their own mutual light and day.',
#  'And myriad happy eyes are bent\nUpon their changeless love alway;\nAs strengthened by their one intent,\nThey pour the flood of life and day.',
#  'So we, through this worldÂ\x92s waning night,\nShall, hand in hand, pursue our way;\nShed round us order, love, and light,\nAnd shine unto the perfect day.']

# %%
#Tokenize the text with words :
words = word_tokenize(text)
#How many words are there? :
print (len(words))
print("\n")
#Print words :
print (words)
# Out:
# 90
#
#
# ['Twin', 'stars', ',', 'aloft', 'in', 'ether', 'clear', ',', 'Around', 'each', 'other', 'roll', 'alway', ',', 'Within', 'one', 'common', 'atmosphere', 'Of', 'their', 'own', 'mutual', 'light', 'and', 'day', '.', 'And', 'myriad', 'happy', 'eyes', 'are', 'bent', 'Upon', 'their', 'changeless', 'love', 'alway', ';', 'As', 'strengthened', 'by', 'their', 'one', 'intent', ',', 'They', 'pour', 'the', 'flood', 'of', 'life', 'and', 'day', '.', 'So', 'we', ',', 'through', 'this', 'worldÂ\x92s', 'waning', 'night', ',', 'Shall', ',', 'hand', 'in', 'hand', ',', 'pursue', 'our', 'way', ';', 'Shed', 'round', 'us', 'order', ',', 'love', ',', 'and', 'light', ',', 'And', 'shine', 'unto', 'the', 'perfect', 'day', '.']

# %%
#Import required libraries :
from nltk.probability import FreqDist
#Find the frequency :
fdist = FreqDist(words)
#Print 10 most common words :
fdist.most_common(10)
# Out:
# [(',', 11),
#  ('their', 3),
#  ('and', 3),
#  ('day', 3),
#  ('.', 3),
#  ('in', 2),
#  ('alway', 2),
#  ('one', 2),
#  ('light', 2),
#  ('And', 2)]

# %%
#Plot the graph for fdist :
import matplotlib.pyplot as plt
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#Empty list to store words:
words_no_punc = []
#Removing punctuation marks :
for w in words:
  if w.isalpha():
      words_no_punc.append(w.lower())
#Print the words without punctution marks :
print (words_no_punc)
print ("\n")
#Length :
print (len(words_no_punc))
# Out:
# ['twin', 'stars', 'aloft', 'in', 'ether', 'clear', 'around', 'each', 'other', 'roll', 'alway', 'within', 'one', 'common', 'atmosphere', 'of', 'their', 'own', 'mutual', 'light', 'and', 'day', 'and', 'myriad', 'happy', 'eyes', 'are', 'bent', 'upon', 'their', 'changeless', 'love', 'alway', 'as', 'strengthened', 'by', 'their', 'one', 'intent', 'they', 'pour', 'the', 'flood', 'of', 'life', 'and', 'day', 'so', 'we', 'through', 'this', 'waning', 'night', 'shall', 'hand', 'in', 'hand', 'pursue', 'our', 'way', 'shed', 'round', 'us', 'order', 'love', 'and', 'light', 'and', 'shine', 'unto', 'the', 'perfect', 'day']
#
#
# 73

# %%
#Frequency distribution :
fdist = FreqDist(words_no_punc)
fdist.most_common(10)
# Out:
# [('and', 5),
#  ('their', 3),
#  ('day', 3),
#  ('in', 2),
#  ('alway', 2),
#  ('one', 2),
#  ('of', 2),
#  ('light', 2),
#  ('love', 2),
#  ('the', 2)]

# %%
#Plot the most common words on grpah:
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from nltk.corpus import stopwords
#List of stopwords
stopwords = stopwords.words("english")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
#Empty list to store clean words :
clean_words = []
for w in words_no_punc:
  if w not in stopwords:
      clean_words.append(w)
print(clean_words)
print("\n")
print(len(clean_words))
# Out:
# ['twin', 'stars', 'aloft', 'ether', 'clear', 'around', 'roll', 'alway', 'within', 'one', 'common', 'atmosphere', 'mutual', 'light', 'day', 'myriad', 'happy', 'eyes', 'bent', 'upon', 'changeless', 'love', 'alway', 'strengthened', 'one', 'intent', 'pour', 'flood', 'life', 'day', 'waning', 'night', 'shall', 'hand', 'hand', 'pursue', 'way', 'shed', 'round', 'us', 'order', 'love', 'light', 'shine', 'unto', 'perfect', 'day']
#
#
# 47

# %%
#Frequency distribution :
fdist = FreqDist(clean_words)
fdist.most_common(10)
# Out:
# [('day', 3),
#  ('alway', 2),
#  ('one', 2),
#  ('light', 2),
#  ('love', 2),
#  ('hand', 2),
#  ('twin', 1),
#  ('stars', 1),
#  ('aloft', 1),
#  ('ether', 1)]

# %%
#Plot the most common words on grpah:
fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#Library to form wordcloud :
from wordcloud import WordCloud
#Library to plot the wordcloud :
import matplotlib.pyplot as plt
#Generating the wordcloud :
wordcloud = WordCloud().generate(text)
#Plot the wordcloud :,
plt.figure(figsize = (8,8))
plt.imshow(wordcloud)
#To remove the axis value :
plt.axis("off")
plt.show()

# %%
#Import required libraries :
import numpy as np
from PIL import Image
from wordcloud import WordCloud

# %%
#Import required libraries :
import numpy as np
from PIL import Image
from wordcloud import WordCloud

# Specify the correct path to the image
image_path = '/content/circle.png'

#Here we are going to use a circle image as mask :
char_mask = np.array(Image.open(image_path))

#Generating wordcloud :
wordcloud = WordCloud(background_color="black",mask=char_mask).generate(text)

#Plot the wordcloud :
plt.figure(figsize = (8,8))
plt.imshow(wordcloud)

#To remove the axis value :
plt.axis("off")
plt.show()

# %%
#Stemming Example :
#Import stemming library :
from nltk.stem import PorterStemmer
porter = PorterStemmer()
#Word-list for stemming :
word_list = ["Walk","Walking","Walkies","Walked"]
for w in word_list:
  print(porter.stem(w))
# Out:
# walk
# walk
# walki
# walk

# %%
#Stemming Example :
#Import stemming library :
from nltk.stem import PorterStemmer
porter = PorterStemmer()
#Word-list for stemming :
word_list = ["walkies","skies","lightens","denies"]
for w in word_list:
  print(porter.stem(w))
# Out:
# walki
# sky
# lighten
# deni

# %%
#Stemming Example :
#Import stemming library :
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer("english")
#Word-list for stemming :
word_list = ["Walk","Walking","Walkies","Walked"]
for w in word_list:
  print(snowball.stem(w))
# Out:
# walk
# walk
# walki
# walk

# %%
#Stemming Example :
#Import stemming library :
from nltk.stem import SnowballStemmer
#Print languages supported :
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
from nltk import WordNetLemmatizer
lemma = WordNetLemmatizer()
word_list = ["Walk","Walking","Walkies","Walked"]
for w in word_list:
  print(lemma.lemmatize(w ,pos="v"))
# Out:
# Walk
# Walking
# Walkies
# Walked

# %%
from nltk import WordNetLemmatizer
lemma = WordNetLemmatizer()
word_list = ["i", "me", "my", "myself", "we", "our", "you"]
for w in word_list:
  print(lemma.lemmatize(w ,pos="v"))
# Out:
# i
# me
# my
# myself
# we
# our
# you

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
print(stemmer.stem('walking'))
# Out:
# walk

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize('walking', pos="v"))
print(lemmatizer.lemmatize('walking', pos="n"))
print(lemmatizer.lemmatize('walking', pos="a"))
print(lemmatizer.lemmatize('walking', pos="r"))
# Out:
# walk
# walking
# walking
# walking

# %%
from nltk import WordNetLemmatizer
lemma = WordNetLemmatizer()
word_list = ["walks","skies","starry","night"]
for w in word_list:
  print(lemma.lemmatize(w))
# Out:
# walk
# sky
# starry
# night
